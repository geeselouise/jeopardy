# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import pandas as pd
import sys
from collections import defaultdict

# %%
csv_file = 'nmf_jq_lemma.csv'
df =pd.read_csv(csv_file)

dataset = 'cohan 0.01, brunswick 0.009, cather 0.009, isotope 0.009, lower 0.009, phosphorus 0.009, swede 0.009, akc 0.008, challenger 0.008, charlotte 0.008'

# %%
wordcloud = WordCloud(width=1000, height=1000, colormap="hsv", background_color="white", margin=0).generate(dataset)

# %%
d2 = 'balcony 0.009, 63 0.008, applause 0.008, britains 0.008, cathedral 0.008, corona 0.008, decorative 0.008, distress 0.008, followers 0.008, lionel 0.008'

# %%
wordcloud = WordCloud(width=1000, height=1000, colormap="hsv", background_color="white", margin=0).generate(d2)

# %%
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.margins(x=0, y=0)
plt.show
plt.savefig('C://Users/louisa/Downloads/topic3.png')
